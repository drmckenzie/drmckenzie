# %% [markdown]
# # Pokemon Match
#
# This file calculates the top x number of attacking pokemon per type for raids (PvE). It lists:
# - the top moves for each type
# - a summary of the pokemon for each type (split by normal/shadow)
# - a combined summary of all pokemon of all types at the end (split norm/shadow)
#
# Use the "Runtime -> Run All" to see all output :)

# %%
import os
import shutil
print(os.getcwd())
# Out:
# /content

# %%
# this bit imports the github, clones and changes the path:
os.chdir('/content')
myDir = './drmckenzie.github.io/'

# WARNING! this will delete any changes to the files you have made
if os.path.isdir(myDir):
    shutil.rmtree(myDir)

# !git clone https://github.com/drmckenzie/drmckenzie.github.io.git

os.chdir(myDir)
print(os.getcwd())
# Out:
# Cloning into 'drmckenzie.github.io'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 176 (delta 107), reused 127 (delta 67), pack-reused 0
# Receiving objects: 100% (176/176), 1.12 MiB | 2.45 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# /content/drmckenzie.github.io

# %% [markdown]
# # You can change these default settings to customise the results:

# %%
# This is the list of types that runs by default:
typeList = ["Normal", "Fire", "Water", "Grass", "Flying", "Fighting", "Poison", "Electric", "Ground", "Rock", "Psychic", "Ice", "Bug", "Ghost", "Steel", "Dragon", "Dark", "Fairy"]

# This is number of pokemon returned per type.
findThisMany = 5

# %%
import pandas as pd
 
import pokemonMatch as match
 
runCases =  'basic'
 
whatFlag = runCases
 
#flag for running cases
#whatFlag = 'both' # 'basic' 'shadow' 'both'
 
# GamePress total CPO filename
gamepressFilenameShadow = 'shadow_comprehensive_dps_gamepress_L35_best_moves.csv'
gamepressFilename = 'basic_comprehensive_dps_gamepress_L35_all_moves.csv'
gamepressFilename = 'all_comprehensive_dps_gamepress_L35_all_moves.csv'
#gamepressFilename = 'mega_comprehensive_dps_gamepress_L35_all_moves.csv'
 
# setting the filters
typeFilter = []
topX = 0
 
# load data
allData = match.getGamepressData(gamepressFilename,typeFilter,topX)
    
# print(list(allData.columns))
 
# type lookup:
allData = match.typeAttackLookup(allData)
 
allData["Shadow"]=False
 
name = allData["Pokemon"]
nameloc = name.str.startswith("Shadow")
allData.loc[nameloc,"Shadow"]=True

# add a tag to the existing data, to say it's top tier
allData["TopPvE"] = False
 
# finding Pokémon with both attack types the same
#typeList = ["Normal", "Fire", "Water", "Grass", "Flying", "Fighting", "Poison", "Electric", "Ground", "Rock", "Psychic", "Ice", "Bug", "Ghost", "Steel", "Dragon", "Dark", "Fairy"]
 
setData = pd.DataFrame() 
 
#findThisMany = 5
 
# Setting empty strings for later
joinedStrings = ""
joinedStringsShad = ""
joinedStringsAll = ""
# setting a list of empty, for listing all the top x later
joinedIntBase = list()
joinedIntShad = list()
 
# big loop now:
for thisType in typeList:
    setDataTemp = match.findBothAttackOfType(allData,thisType)
    setData = pd.concat([setData,setDataTemp.head(findThisMany)],sort=False)
    topTypeSet = setDataTemp[["Pokemon","#","DPS^3*TDO","Fast move","Special move","TypeFast","Shadow"]]
    topTypeSetPrint = setDataTemp[["Pokemon","DPS^3*TDO","Fast move","Special move","TypeFast"]]
    topTypeSetPrint = topTypeSetPrint.iloc[:findThisMany]
    print(topTypeSetPrint.to_string(index=False))
    
    print(" ")
    
    # select top X
    topTypeSet = topTypeSet.head(findThisMany)
 
    # separate Shadow from non-Shadow
    shadTop = topTypeSet[topTypeSet["Shadow"]==True]
    shadTopNot = topTypeSet[topTypeSet["Shadow"]==False]
 
    #print(shadTopNot.head(5))
 
    #print(len(shadTopNot))
 
    if len(shadTopNot) > 0:
        # base
        shadString = ""
        typeListTemp = shadTopNot["#"].head(findThisMany)
        joinedIntBase.extend(typeListTemp)
        typeStr = [str(int(inte)) for inte in typeListTemp]
        typeStr = ",".join(typeStr)
        #print(typeStr)
        allString = "Type: "+thisType+" top "+str(findThisMany)+" - "+typeStr+shadString
    else:
        allString = "Type: "+thisType+" not found in base"
    print(allString) 
 
    if len(shadTop) > 0:
        # shadow
        shadString = "&shadow"
        typeListTemp = shadTop["#"].head(findThisMany)
        joinedIntShad.extend(typeListTemp)
        typeStr = [str(int(inte)) for inte in typeListTemp]
        typeStr = ",".join(typeStr)
        #print(typeStr)
        allStringShad = "Type: Shadow "+thisType+" top "+str(findThisMany)+" - "+typeStr+shadString
    else:
        allStringShad = "Type: "+thisType+" not found in shadow"
    print(allStringShad)  
 
    joinedStrings = joinedStrings + "\n" + allString
    joinedStringsShad = joinedStringsShad + "\n" + allStringShad
 
    joinedStringsAll = joinedStringsAll + "\n" + allString + "\n" + allStringShad
 
    print(" ")
 
print("------------------------------------")
print("This is a summary list of pokemon per types")
 
print(joinedStrings)
 
print(joinedStringsShad)
 
print(joinedStringsAll)
 
print("")
print("------------------------------------")
print("This is a summary list of all pokemon gathered together of all types")
 
# make the lists sorted and unique:
joinedIntBase = list(sorted(set(joinedIntBase)))
joinedIntShad = list(sorted(set(joinedIntShad)))
 
typeStr = [str(int(inte)) for inte in joinedIntBase]
typeStr = ",".join(typeStr)
print("List of combined top "+str(findThisMany)+" base pokemon of all types: ")
print(typeStr)

print("")
 
typeStr = [str(int(inte)) for inte in joinedIntShad]
typeStr = ",".join(typeStr)
print("List of combined top "+str(findThisMany)+" Shadow pokemon of all types: ")
print(typeStr+"&shadow")
 
# mark this set as top tier for the future
setData["TopPvE"] = True
 
#print(allData[allData["Pokemon"]=="Kyogre"])
 
#print(allData.head(20))
# Out:
#           Pokemon  DPS^3*TDO Fast move Special move TypeFast
#  Shadow Porygon-Z     1781.3   Lock-On   Hyper Beam   Normal
#         Porygon-Z     1255.1   Lock-On       Return   Normal
#    Shadow Ambipom      807.2   Scratch   Hyper Beam   Normal
#   Shadow Porygon2      769.7   Lock-On   Hyper Beam   Normal
#           Ambipom      599.5   Scratch       Return   Normal
#
# Type: Normal top 5 - 474,424
# Type: Shadow Normal top 5 - 474,424,233&shadow
#
#           Pokemon  DPS^3*TDO  Fast move  Special move TypeFast
#      Shadow Entei     3031.7  Fire Fang      Overheat     Fire
#          Reshiram     2943.1  Fire Fang      Overheat     Fire
#    Shadow Moltres     2916.5  Fire Spin      Overheat     Fire
#  Shadow Charizard     2421.3  Fire Spin    Blast Burn     Fire
#   Shadow Arcanine     1824.6  Fire Fang  Flamethrower     Fire
#
# Type: Fire top 5 - 643
# Type: Shadow Fire top 5 - 244,146,6,59&shadow
#
#          Pokemon  DPS^3*TDO  Fast move  Special move TypeFast
#  Shadow Swampert     2747.5  Water Gun  Hydro Cannon    Water
#           Kyogre     2190.4  Waterfall          Surf    Water
#  Shadow Gyarados     1845.1  Waterfall    Hydro Pump    Water
#         Swampert     1527.5  Water Gun  Hydro Cannon    Water
#          Kingler     1462.5     Bubble    Crabhammer    Water
#
# Type: Water top 5 - 382,260,99
# Type: Shadow Water top 5 - 260,130&shadow
#
#            Pokemon  DPS^3*TDO    Fast move  Special move TypeFast
#    Shadow Torterra     2013.3   Razor Leaf  Frenzy Plant    Grass
#    Shadow Venusaur     1995.1    Vine Whip  Frenzy Plant    Grass
#   Shadow Exeggutor     1386.3  Bullet Seed    Solar Beam    Grass
#  Shadow Victreebel     1216.9   Razor Leaf    Leaf Blade    Grass
#           Roserade     1179.2   Razor Leaf    Grass Knot    Grass
#
# Type: Grass top 5 - 407
# Type: Shadow Grass top 5 - 389,3,103,71&shadow
#
#         Pokemon  DPS^3*TDO              Fast move Special move TypeFast
#  Shadow Moltres     3638.2            Wing Attack   Sky Attack   Flying
#         Moltres     2024.2            Wing Attack   Sky Attack   Flying
#           Ho-Oh     1553.8  Hidden Power (Flying)   Brave Bird   Flying
#        Rayquaza     1445.0              Air Slash    Hurricane   Flying
#       Honchkrow     1260.9                   Peck   Sky Attack   Flying
#
# Type: Flying top 5 - 146,250,384,430
# Type: Shadow Flying top 5 - 146&shadow
#
#         Pokemon  DPS^3*TDO Fast move   Special move  TypeFast
#  Shadow Machamp     2691.5   Counter  Dynamic Punch  Fighting
#         Lucario     2002.4   Counter    Aura Sphere  Fighting
#      Conkeldurr     1941.9   Counter  Dynamic Punch  Fighting
#         Machamp     1495.9   Counter  Dynamic Punch  Fighting
#        Hariyama     1227.8   Counter  Dynamic Punch  Fighting
#
# Type: Fighting top 5 - 448,534,68,297
# Type: Shadow Fighting top 5 - 68&shadow
#
#            Pokemon  DPS^3*TDO   Fast move Special move TypeFast
#           Roserade     1200.1  Poison Jab  Sludge Bomb   Poison
#  Shadow Victreebel     1175.5        Acid  Sludge Bomb   Poison
#   Shadow Vileplume     1151.9        Acid  Sludge Bomb   Poison
#         Shadow Muk     1000.9  Poison Jab    Gunk Shot   Poison
#    Shadow Skuntank      984.1  Poison Jab  Sludge Bomb   Poison
#
# Type: Poison top 5 - 407
# Type: Shadow Poison top 5 - 71,45,89,435&shadow
#
#            Pokemon  DPS^3*TDO      Fast move Special move  TypeFast
#      Shadow Raikou     3160.8  Thunder Shock  Wild Charge  Electric
#  Shadow Electivire     2752.0  Thunder Shock  Wild Charge  Electric
#      Shadow Zapdos     2734.7  Thunder Shock  Thunderbolt  Electric
#             Zekrom     2585.4    Charge Beam  Wild Charge  Electric
#   Shadow Magnezone     2468.3          Spark  Wild Charge  Electric
#
# Type: Electric top 5 - 644
# Type: Shadow Electric top 5 - 243,466,145,462&shadow
#
#          Pokemon  DPS^3*TDO Fast move Special move TypeFast
#          Groudon     1651.1  Mud Shot   Earthquake   Ground
#         Garchomp     1510.5  Mud Shot   Earthquake   Ground
#        Excadrill     1095.4  Mud Shot    Drill Run   Ground
#  Shadow Swampert      976.1  Mud Shot   Earthquake   Ground
#    Shadow Flygon      976.1  Mud Shot  Earth Power   Ground
#
# Type: Ground top 5 - 383,445,530
# Type: Shadow Ground top 5 - 260,330&shadow
#
#            Pokemon  DPS^3*TDO   Fast move  Special move TypeFast
#   Shadow Tyranitar     2218.3  Smack Down    Stone Edge     Rock
#          Rhyperior     1971.6  Smack Down  Rock Wrecker     Rock
#          Rampardos     1873.1  Smack Down    Rock Slide     Rock
#          Terrakion     1576.1  Smack Down    Rock Slide     Rock
#  Shadow Aerodactyl     1381.8  Rock Throw    Rock Slide     Rock
#
# Type: Rock top 5 - 464,409,639
# Type: Shadow Rock top 5 - 248,142&shadow
#
#           Pokemon  DPS^3*TDO     Fast move Special move TypeFast
#     Shadow Mewtwo     8756.0     Confusion    Psystrike  Psychic
#            Mewtwo     4830.9     Confusion    Psystrike  Psychic
#  Shadow Metagross     3139.5  Zen Headbutt      Psychic  Psychic
#   Shadow Alakazam     2742.0     Confusion      Psychic  Psychic
#  Shadow Exeggutor     2279.3     Confusion      Psychic  Psychic
#
# Type: Psychic top 5 - 150
# Type: Shadow Psychic top 5 - 150,376,65,103&shadow
#
#           Pokemon  DPS^3*TDO     Fast move Special move TypeFast
#  Shadow Mamoswine     2808.7   Powder Snow    Avalanche      Ice
#    Shadow Weavile     1939.6     Ice Shard    Avalanche      Ice
#         Mamoswine     1528.6   Powder Snow    Avalanche      Ice
#           Glaceon     1131.2  Frost Breath    Avalanche      Ice
#           Weavile     1075.1     Ice Shard    Avalanche      Ice
#
# Type: Ice top 5 - 473,471,461
# Type: Shadow Ice top 5 - 473,461&shadow
#
#         Pokemon  DPS^3*TDO    Fast move Special move TypeFast
#   Shadow Pinsir     1355.2     Bug Bite    X-Scissor      Bug
#   Shadow Scizor     1295.0  Fury Cutter    X-Scissor      Bug
#  Shadow Scyther      938.4  Fury Cutter    X-Scissor      Bug
#          Pinsir      773.5     Bug Bite    X-Scissor      Bug
#      Escavalier      764.0     Bug Bite     Megahorn      Bug
#
# Type: Bug top 5 - 127,589
# Type: Shadow Bug top 5 - 127,212,123&shadow
#
#           Pokemon  DPS^3*TDO    Fast move Special move TypeFast
#        Chandelure     1878.3          Hex  Shadow Ball    Ghost
#            Gengar     1679.1         Lick  Shadow Ball    Ghost
#    Shadow Banette     1466.7  Shadow Claw  Shadow Ball    Ghost
#  Shadow Mismagius     1354.2          Hex  Shadow Ball    Ghost
#           Banette      810.0  Shadow Claw  Shadow Ball    Ghost
#
# Type: Ghost top 5 - 609,94,354
# Type: Shadow Ghost top 5 - 354,429&shadow
#
#           Pokemon  DPS^3*TDO     Fast move Special move TypeFast
#  Shadow Metagross     5211.4  Bullet Punch  Meteor Mash    Steel
#         Metagross     2915.4  Bullet Punch  Meteor Mash    Steel
#            Dialga     1812.4    Metal Claw    Iron Head    Steel
#         Excadrill     1172.0    Metal Claw    Iron Head    Steel
#     Shadow Scizor     1166.6  Bullet Punch    Iron Head    Steel
#
# Type: Steel top 5 - 376,483,530
# Type: Shadow Steel top 5 - 376,212&shadow
#
#           Pokemon  DPS^3*TDO    Fast move  Special move TypeFast
#  Shadow Salamence     4761.4  Dragon Tail       Outrage   Dragon
#  Shadow Dragonite     4208.4  Dragon Tail       Outrage   Dragon
#          Rayquaza     2875.2  Dragon Tail       Outrage   Dragon
#            Palkia     2671.8  Dragon Tail  Draco Meteor   Dragon
#         Salamence     2637.6  Dragon Tail       Outrage   Dragon
#
# Type: Dragon top 5 - 384,484,373
# Type: Shadow Dragon top 5 - 373,149&shadow
#
#           Pokemon  DPS^3*TDO Fast move Special move TypeFast
#  Shadow Tyranitar     2192.6      Bite       Crunch     Dark
#    Shadow Weavile     2136.6     Snarl    Foul Play     Dark
#           Darkrai     1771.6     Snarl   Dark Pulse     Dark
#   Shadow Houndoom     1497.7     Snarl    Foul Play     Dark
#         Hydreigon     1325.1      Bite   Dark Pulse     Dark
#
# Type: Dark top 5 - 491,635
# Type: Shadow Dark top 5 - 248,461,229&shadow
#
#           Pokemon  DPS^3*TDO Fast move    Special move TypeFast
#  Shadow Gardevoir     1898.2     Charm  Dazzling Gleam    Fairy
#          Togekiss     1123.1     Charm  Dazzling Gleam    Fairy
#         Gardevoir     1063.7     Charm  Dazzling Gleam    Fairy
#          Granbull      702.9     Charm      Play Rough    Fairy
#           Beartic      558.0     Charm      Play Rough    Fairy
#
# Type: Fairy top 5 - 468,282,210,614
# Type: Shadow Fairy top 5 - 282&shadow
#
# ------------------------------------
# This is a summary list of pokemon per types
#
# Type: Normal top 5 - 474,424
# Type: Fire top 5 - 643
# Type: Water top 5 - 382,260,99
# Type: Grass top 5 - 407
# Type: Flying top 5 - 146,250,384,430
# Type: Fighting top 5 - 448,534,68,297
# Type: Poison top 5 - 407
# Type: Electric top 5 - 644
# Type: Ground top 5 - 383,445,530
# Type: Rock top 5 - 464,409,639
# Type: Psychic top 5 - 150
# Type: Ice top 5 - 473,471,461
# Type: Bug top 5 - 127,589
# Type: Ghost top 5 - 609,94,354
# Type: Steel top 5 - 376,483,530
# Type: Dragon top 5 - 384,484,373
# Type: Dark top 5 - 491,635
# Type: Fairy top 5 - 468,282,210,614
#
# Type: Shadow Normal top 5 - 474,424,233&shadow
# Type: Shadow Fire top 5 - 244,146,6,59&shadow
# Type: Shadow Water top 5 - 260,130&shadow
# Type: Shadow Grass top 5 - 389,3,103,71&shadow
# Type: Shadow Flying top 5 - 146&shadow
# Type: Shadow Fighting top 5 - 68&shadow
# Type: Shadow Poison top 5 - 71,45,89,435&shadow
# Type: Shadow Electric top 5 - 243,466,145,462&shadow
# Type: Shadow Ground top 5 - 260,330&shadow
# Type: Shadow Rock top 5 - 248,142&shadow
# Type: Shadow Psychic top 5 - 150,376,65,103&shadow
# Type: Shadow Ice top 5 - 473,461&shadow
# Type: Shadow Bug top 5 - 127,212,123&shadow
# Type: Shadow Ghost top 5 - 354,429&shadow
# Type: Shadow Steel top 5 - 376,212&shadow
# Type: Shadow Dragon top 5 - 373,149&shadow
# Type: Shadow Dark top 5 - 248,461,229&shadow
# Type: Shadow Fairy top 5 - 282&shadow
#
# Type: Normal top 5 - 474,424
# Type: Shadow Normal top 5 - 474,424,233&shadow
# Type: Fire top 5 - 643
# Type: Shadow Fire top 5 - 244,146,6,59&shadow
# Type: Water top 5 - 382,260,99
# Type: Shadow Water top 5 - 260,130&shadow
# Type: Grass top 5 - 407
# Type: Shadow Grass top 5 - 389,3,103,71&shadow
# Type: Flying top 5 - 146,250,384,430
# Type: Shadow Flying top 5 - 146&shadow
# Type: Fighting top 5 - 448,534,68,297
# Type: Shadow Fighting top 5 - 68&shadow
# Type: Poison top 5 - 407
# Type: Shadow Poison top 5 - 71,45,89,435&shadow
# Type: Electric top 5 - 644
# Type: Shadow Electric top 5 - 243,466,145,462&shadow
# Type: Ground top 5 - 383,445,530
# Type: Shadow Ground top 5 - 260,330&shadow
# Type: Rock top 5 - 464,409,639
# Type: Shadow Rock top 5 - 248,142&shadow
# Type: Psychic top 5 - 150
# Type: Shadow Psychic top 5 - 150,376,65,103&shadow
# Type: Ice top 5 - 473,471,461
# Type: Shadow Ice top 5 - 473,461&shadow
# Type: Bug top 5 - 127,589
# Type: Shadow Bug top 5 - 127,212,123&shadow
# Type: Ghost top 5 - 609,94,354
# Type: Shadow Ghost top 5 - 354,429&shadow
# Type: Steel top 5 - 376,483,530
# Type: Shadow Steel top 5 - 376,212&shadow
# Type: Dragon top 5 - 384,484,373
# Type: Shadow Dragon top 5 - 373,149&shadow
# Type: Dark top 5 - 491,635
# Type: Shadow Dark top 5 - 248,461,229&shadow
# Type: Fairy top 5 - 468,282,210,614
# Type: Shadow Fairy top 5 - 282&shadow
#
# ------------------------------------
# This is a summary list of all pokemon gathered together of all types
# List of combined top 5 base pokemon of all types:
# 68,94,99,127,146,150,210,250,260,282,297,354,373,376,382,383,384,407,409,424,430,445,448,461,464,468,471,473,474,483,484,491,530,534,589,609,614,635,639,643,644
#
# List of combined top 5 Shadow pokemon of all types:
# 3,6,45,59,65,68,71,89,103,123,127,130,142,145,146,149,150,212,229,233,243,244,248,260,282,330,354,373,376,389,424,429,435,461,462,466,473,474&shadow

# %% [markdown]
# #TODO - instead of doing just the top move, do 95% or 90% is acceptable???

# %%
print(allData.loc[1,"Shadow"]==False)
setData.head(25)
# Out:
# True
#                 Pokemon              Fast move  ... Shadow  TopPvE
# 674    Shadow Porygon-Z                Lock-On  ...   True    True
# 2129          Porygon-Z                Lock-On  ...  False    True
# 705      Shadow Ambipom                Scratch  ...   True    True
# 676     Shadow Porygon2                Lock-On  ...   True    True
# 2246            Ambipom                Scratch  ...  False    True
# 2284       Shadow Entei              Fire Fang  ...   True    True
# 2285           Reshiram              Fire Fang  ...  False    True
# 2289     Shadow Moltres              Fire Spin  ...   True    True
# 8397   Shadow Charizard              Fire Spin  ...   True    True
# 817     Shadow Arcanine              Fire Fang  ...   True    True
# 8566    Shadow Swampert              Water Gun  ...   True    True
# 6995             Kyogre              Waterfall  ...  False    True
# 3056    Shadow Gyarados              Waterfall  ...   True    True
# 8568           Swampert              Water Gun  ...  False    True
# 9050            Kingler                 Bubble  ...  False    True
# 8553    Shadow Torterra             Razor Leaf  ...   True    True
# 8557    Shadow Venusaur              Vine Whip  ...   True    True
# 1478   Shadow Exeggutor            Bullet Seed  ...   True    True
# 1687  Shadow Victreebel             Razor Leaf  ...   True    True
# 3649           Roserade             Razor Leaf  ...  False    True
# 7030     Shadow Moltres            Wing Attack  ...   True    True
# 7031            Moltres            Wing Attack  ...  False    True
# 8495              Ho-Oh  Hidden Power (Flying)  ...  False    True
# 6804           Rayquaza              Air Slash  ...  False    True
# 7050          Honchkrow                   Peck  ...  False    True
#
# [25 rows x 15 columns]

# %%
calcyFilename = 'calcyIV_history_20210316_110351.csv'

# %% [markdown]
# Note for later:
# This lists the number of pokemon with similar attacks:
# Result3 = calcy.groupby(['Pokemon',"#",'Fast move','Special move'  ,"Shadow"]).size()

# %%
moreData = match.calcyImportAndReturnTopNumbers(calcyFilename,allData)
moreData.head(5)

temp = moreData[moreData["ShadowForm"]==2]
temp.head(5)

calcyData = pd.read_csv(calcyFilename, encoding='utf8')
calcyData.head(5)

# read the csv files into dataframes
calcyData = pd.read_csv(calcyFilename, encoding='utf8')

# get the data we're interested in. Name and score
calcy = calcyData[["Name","Nr","Fast move","Special move","Special move 2","CP","Saved","Lucky","ShadowForm"]]

# drop those that are not saved:
calcy = calcy[calcy["Saved"]==1]

#TODO do something with Geodude Normal etc.
    
# rename shadow and XL to remove the quotation marks
#calcy['Shadow'] = calcy['Shadow'].str.replace(r'"', '')

# rename columns                                 
calcy = calcy.rename(columns={'Name': 'Pokemon'})
calcy = calcy.rename(columns={'Nr': '#'})

# drop any blank fast/special moves:
calcy = calcy[~calcy["Fast move"].str.startswith('-')]
calcy = calcy[~calcy["Fast move"].str.startswith(" -")]
calcy = calcy[~calcy["Special move"].str.startswith("-")]
calcy = calcy[~calcy["Special move"].str.startswith(' -')]

# rename - whitespace. Infuriating
calcy['Fast move'] = calcy['Fast move'].str.replace(r'-', ' ')
calcy['Special move'] = calcy['Special move'].str.replace(r'-', ' ')
calcy['Special move 2'] = calcy['Special move 2'].str.replace(r'-', ' ')

# move the "shadow" tag to the front rather than the back
calcyShadowFound = calcy["ShadowForm"]==2
calcy['Pokemon'] = calcy['Pokemon'].str.replace(r' Shadow', '')
calcy.loc[calcyShadowFound,'Pokemon'] = 'Shadow ' + calcy.loc[calcyShadowFound,'Pokemon'].astype(str)

# create shadow tag
calcy["Shadow"] = False
calcy.loc[calcyShadowFound,'Shadow'] = True

# merge : this needs to be a 2 step process
#Result1 = calcy.merge(setData,how='inner', on=['Pokemon',"#",'Fast move','Special move'  ,"Shadow"])
#Result2 = calcy.merge(setData,how='inner', on=['Pokemon',"#",'Fast move','Special move 2',"Shadow"])
Result1 = setData.merge(calcy,how='outer', on=['Pokemon',"#",'Fast move','Special move'  ,"Shadow"])
Result2 = setData.merge(calcy,how='outer', on=['Pokemon',"#",'Fast move','Special move 2',"Shadow"])

# rename columns
Result1 = Result1.rename(columns={'Special move 2_x': 'Special move 2'})
Result1 = Result1.rename(columns={'Special move 2_y': 'Temp'})
Result2 = Result2.rename(columns={'Special move_x': 'Special move'})
Result2 = Result2.rename(columns={'Special move_y': 'Temp'})

Result = pd.concat([Result1,Result2],sort=False)

# drop the column
Result.drop(columns=['Temp'], inplace=True)

# https://stackoverflow.com/questions/50293496/count-occurrences-of-item-in-one-dataframe-in-another

count_series = Result["Pokemon"].value_counts()

count_series.head(50)

Result.head(50)
# Out:
#               Pokemon              Fast move  ... Lucky  ShadowForm
# 0    Shadow Porygon-Z                Lock-On  ...   NaN         NaN
# 1           Porygon-Z                Lock-On  ...   NaN         NaN
# 2      Shadow Ambipom                Scratch  ...   NaN         NaN
# 3     Shadow Porygon2                Lock-On  ...   NaN         NaN
# 4             Ambipom                Scratch  ...   NaN         NaN
# 5        Shadow Entei              Fire Fang  ...   NaN         NaN
# 6            Reshiram              Fire Fang  ...   NaN         NaN
# 7      Shadow Moltres              Fire Spin  ...   NaN         NaN
# 8    Shadow Charizard              Fire Spin  ...   NaN         NaN
# 9     Shadow Arcanine              Fire Fang  ...   NaN         NaN
# 10    Shadow Swampert              Water Gun  ...   NaN         NaN
# 11             Kyogre              Waterfall  ...   1.0         0.0
# 12    Shadow Gyarados              Waterfall  ...   NaN         NaN
# 13           Swampert              Water Gun  ...   1.0         1.0
# 14            Kingler                 Bubble  ...   NaN         NaN
# 15    Shadow Torterra             Razor Leaf  ...   NaN         NaN
# 16    Shadow Venusaur              Vine Whip  ...   NaN         NaN
# 17   Shadow Exeggutor            Bullet Seed  ...   NaN         NaN
# 18  Shadow Victreebel             Razor Leaf  ...   NaN         NaN
# 19           Roserade             Razor Leaf  ...   1.0         0.0
# 20     Shadow Moltres            Wing Attack  ...   NaN         NaN
# 21            Moltres            Wing Attack  ...   1.0         1.0
# 22              Ho-Oh  Hidden Power (Flying)  ...   NaN         NaN
# 23           Rayquaza              Air Slash  ...   NaN         NaN
# 24          Honchkrow                   Peck  ...   NaN         NaN
# 25     Shadow Machamp                Counter  ...   1.0         2.0
# 26     Shadow Machamp                Counter  ...   1.0         2.0
# 27     Shadow Machamp                Counter  ...   1.0         2.0
# 28            Lucario                Counter  ...   NaN         NaN
# 29         Conkeldurr                Counter  ...   NaN         NaN
# 30            Machamp                Counter  ...   NaN         NaN
# 31           Hariyama                Counter  ...   1.0         0.0
# 32           Hariyama                Counter  ...   1.0         0.0
# 33           Hariyama                Counter  ...   1.0         0.0
# 34           Hariyama                Counter  ...   1.0         0.0
# 35           Roserade             Poison Jab  ...   NaN         NaN
# 36  Shadow Victreebel                   Acid  ...   NaN         NaN
# 37   Shadow Vileplume                   Acid  ...   NaN         NaN
# 38         Shadow Muk             Poison Jab  ...   NaN         NaN
# 39    Shadow Skuntank             Poison Jab  ...   NaN         NaN
# 40      Shadow Raikou          Thunder Shock  ...   NaN         NaN
# 41  Shadow Electivire          Thunder Shock  ...   1.0         2.0
# 42  Shadow Electivire          Thunder Shock  ...   1.0         2.0
# 43      Shadow Zapdos          Thunder Shock  ...   NaN         NaN
# 44             Zekrom            Charge Beam  ...   NaN         NaN
# 45   Shadow Magnezone                  Spark  ...   NaN         NaN
# 46            Groudon               Mud Shot  ...   1.0         0.0
# 47           Garchomp               Mud Shot  ...   NaN         NaN
# 48          Excadrill               Mud Shot  ...   NaN         NaN
# 49    Shadow Swampert               Mud Shot  ...   NaN         NaN
#
# [50 rows x 19 columns]

# %%
# This is for all data, but with any pokemon found that has either a fast, or special, or special2 move that is optimal (saved)

Result3 = setData.merge(calcy,how='outer', on=['Pokemon',"#",'Fast move'     ,"Shadow"])
Result4 = setData.merge(calcy,how='outer', on=['Pokemon',"#",'Special move'  ,"Shadow"])
Result5 = setData.merge(calcy,how='outer', on=['Pokemon',"#",'Special move 2',"Shadow"])

# rename columns
Result3 = Result3.rename(columns={'Special move_y': 'Temp'})
Result3 = Result3.rename(columns={'Special move 2_y': 'Temp2'})
Result3 = Result3.rename(columns={'Special move_x': 'Special move'})
Result3 = Result3.rename(columns={'Special move 2_x': 'Special move 2'})

Result4 = Result4.rename(columns={'Fast move_y': 'Temp'})
Result4 = Result4.rename(columns={'Fast move_x': 'Fast move'})
Result4 = Result4.rename(columns={'Special move 2_y': 'Temp2'})
Result4 = Result4.rename(columns={'Special move 2_x': 'Special move 2'})

Result5 = Result5.rename(columns={'Fast move_y': 'Temp'})
Result5 = Result5.rename(columns={'Fast move_x': 'Fast move'})
Result5 = Result5.rename(columns={'Special move_y': 'Temp2'})
Result5 = Result5.rename(columns={'Special move_x': 'Special move'})

ResultAny = pd.concat([Result3,Result4,Result5],sort=False)

# drop the column
ResultAny.drop(columns=['Temp'], inplace=True)
ResultAny.drop(columns=['Temp2'], inplace=True)

# ResultAny.head(40)

ResultJustPokemon = setData.merge(calcy,how='outer', on=['Pokemon',"#","Shadow"])
ResultJustPokemon = ResultJustPokemon.rename(columns={'Fast move_x': 'Fast move'})
ResultJustPokemon = ResultJustPokemon.rename(columns={'Special move_x': 'Special move'})
ResultJustPokemon = ResultJustPokemon.rename(columns={'Special move 2_x': 'Special move 2'})

ResultJustPokemon.head(40)
# Out:
#              Pokemon    Fast move  Special move  ...  Saved  Lucky  ShadowForm
# 0   Shadow Porygon-Z      Lock-On    Hyper Beam  ...    NaN    NaN         NaN
# 1          Porygon-Z      Lock-On        Return  ...    1.0    1.0         1.0
# 2          Porygon-Z      Lock-On        Return  ...    1.0    1.0         1.0
# 3     Shadow Ambipom      Scratch    Hyper Beam  ...    NaN    NaN         NaN
# 4    Shadow Porygon2      Lock-On    Hyper Beam  ...    NaN    NaN         NaN
# 5            Ambipom      Scratch        Return  ...    1.0    1.0         1.0
# 6       Shadow Entei    Fire Fang      Overheat  ...    1.0    1.0         2.0
# 7           Reshiram    Fire Fang      Overheat  ...    NaN    NaN         NaN
# 8     Shadow Moltres    Fire Spin      Overheat  ...    NaN    NaN         NaN
# 9     Shadow Moltres  Wing Attack    Sky Attack  ...    NaN    NaN         NaN
# 10  Shadow Charizard    Fire Spin    Blast Burn  ...    NaN    NaN         NaN
# 11   Shadow Arcanine    Fire Fang  Flamethrower  ...    NaN    NaN         NaN
# 12   Shadow Swampert    Water Gun  Hydro Cannon  ...    NaN    NaN         NaN
# 13   Shadow Swampert     Mud Shot    Earthquake  ...    NaN    NaN         NaN
# 14            Kyogre    Waterfall          Surf  ...    1.0    1.0         0.0
# 15            Kyogre    Waterfall          Surf  ...    1.0    1.0         0.0
# 16            Kyogre    Waterfall          Surf  ...    1.0    1.0         0.0
# 17            Kyogre    Waterfall          Surf  ...    1.0    0.0         0.0
# 18            Kyogre    Waterfall          Surf  ...    1.0    1.0         0.0
# 19   Shadow Gyarados    Waterfall    Hydro Pump  ...    1.0    1.0         2.0
# 20   Shadow Gyarados    Waterfall    Hydro Pump  ...    1.0    1.0         2.0
# 21   Shadow Gyarados    Waterfall    Hydro Pump  ...    1.0    1.0         2.0
# 22   Shadow Gyarados    Waterfall    Hydro Pump  ...    1.0    1.0         2.0
# 23          Swampert    Water Gun  Hydro Cannon  ...    1.0    1.0         1.0
# 24          Swampert    Water Gun  Hydro Cannon  ...    1.0    1.0         1.0
# 25          Swampert    Water Gun  Hydro Cannon  ...    1.0    1.0         1.0
# 26          Swampert    Water Gun  Hydro Cannon  ...    1.0    1.0         1.0
# 27          Swampert    Water Gun  Hydro Cannon  ...    1.0    1.0         1.0
# 28          Swampert    Water Gun  Hydro Cannon  ...    1.0    1.0         1.0
# 29           Kingler       Bubble    Crabhammer  ...    1.0    1.0         1.0
# 30           Kingler       Bubble    Crabhammer  ...    1.0    1.0         1.0
# 31           Kingler       Bubble    Crabhammer  ...    1.0   -1.0         1.0
# 32           Kingler       Bubble    Crabhammer  ...    1.0    1.0         1.0
# 33           Kingler       Bubble    Crabhammer  ...    1.0   -1.0         1.0
# 34           Kingler       Bubble    Crabhammer  ...    1.0    1.0         1.0
# 35           Kingler       Bubble    Crabhammer  ...    1.0    1.0         1.0
# 36           Kingler       Bubble    Crabhammer  ...    1.0    1.0         1.0
# 37   Shadow Torterra   Razor Leaf  Frenzy Plant  ...    1.0    1.0         2.0
# 38   Shadow Venusaur    Vine Whip  Frenzy Plant  ...    1.0    1.0         2.0
# 39   Shadow Venusaur    Vine Whip  Frenzy Plant  ...    1.0    1.0         2.0
#
# [40 rows x 24 columns]

# %%
# counting the data manually
setData["FoundCountExact"] = 0
setData["FoundCountAny"] = 0
setData["FoundCountJustPokemon"] = 0
setData["FoundStr"] = ""

for index, row in setData.iterrows():
    thisPokemon = row["Pokemon"]
    
    # count number of exact matches (fast and any special) in results db
    caseExact1 = Result['Pokemon'] == thisPokemon
    caseExact2 = Result['CP'] > 0
    caseExactBoth = caseExact1 & caseExact2
    # any move count
    caseAny1 = ResultAny['Pokemon'] == thisPokemon
    caseAny2 = ResultAny['CP'] > 0
    caseAnyBoth = caseAny1 & caseAny2
    #Just pokemon count
    caseJP1 = ResultJustPokemon['Pokemon'] == thisPokemon
    caseJP2 = ResultJustPokemon['CP'] > 0
    caseJPBoth = caseJP1 & caseJP2

    # convert this into a list we can copy/paste for pokemon go:
    listExactOut = Result.loc[caseExactBoth,'CP']
    listAnyOut = ResultAny.loc[caseAnyBoth,'CP']
    listJPOut = ResultJustPokemon.loc[caseJPBoth,'CP']

    typeStr = ["CP"+str(int(inte)) for inte in listExactOut]
    typeStr = ",".join(typeStr)
    # print(typeStr)
    # put this in the setData db again
    setIndex = setData["Pokemon"]==thisPokemon
    if len(listExactOut) == 0:
        setData.loc[setIndex,"FoundStr"] = ""
    elif thisPokemon.startswith('Shadow '):
        thisPokemon = thisPokemon.replace(r'Shadow ', '')   
        setData.loc[setIndex,"FoundStr"] = thisPokemon + "&shadow&" + typeStr
    else:
        setData.loc[setIndex,"FoundStr"] = thisPokemon + "&" + typeStr
    # how many we found
    setData.loc[setIndex,"FoundCountExact"] = len(listExactOut) 
    setData.loc[setIndex,"FoundCountAny"] = len(listAnyOut) 
    setData.loc[setIndex,"FoundCountJustPokemon"] = len(listJPOut) 

setData.head(10)
# Out:
#                Pokemon  Fast move  ... FoundCountAny  FoundCountJustPokemon
# 674   Shadow Porygon-Z    Lock-On  ...             0                      0
# 2129         Porygon-Z    Lock-On  ...             6                      2
# 705     Shadow Ambipom    Scratch  ...             0                      0
# 676    Shadow Porygon2    Lock-On  ...             0                      0
# 2246           Ambipom    Scratch  ...             3                      1
# 2284      Shadow Entei  Fire Fang  ...             3                      1
# 2285          Reshiram  Fire Fang  ...             0                      0
# 2289    Shadow Moltres  Fire Spin  ...             0                      0
# 8397  Shadow Charizard  Fire Spin  ...             0                      0
# 817    Shadow Arcanine  Fire Fang  ...             0                      0
#
# [10 rows x 20 columns]
